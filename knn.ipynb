# %%
import os 
print(os.getcwd())
# Out:
# c:\Users\Istiak\Desktop\Stroke_Predictor(2)\KNN

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\Istiak\Desktop\Stroke_Predictor(2)\cleaned_data.csv')
df = df.drop(columns=['ever_married'])


df.head()
# Out:
#       id  gender   age  hypertension  heart_disease      work_type  \
# 0   9046    Male  67.0             0              1        Private
# 1  31112    Male  80.0             0              1        Private
# 2  60182  Female  49.0             0              0        Private
# 3   1665  Female  79.0             1              0  Self-employed
# 4  56669    Male  81.0             0              0        Private
#
#   Residence_type  avg_glucose_level   bmi   smoking_status  stroke
# 0          Urban             228.69  36.6  formerly smoked       1
# 1          Rural             105.92  32.5     never smoked       1
# 2          Urban             171.23  34.4           smokes       1
# 3          Rural             174.12  24.0     never smoked       1
# 4          Urban             186.21  29.0  formerly smoked       1

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score 
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
import numpy as np
from sklearn.model_selection import GridSearchCV

X = df.drop('stroke', axis=1)
y = df['stroke']

numerical_cols = X.select_dtypes(include=['int64', 'float64']).columns
categorical_cols = X.select_dtypes(include=['object']).columns

preprocessor = ColumnTransformer(
    transformers=[
        ('num', StandardScaler(), numerical_cols),   # Scaling numerical features
        ('cat', OneHotEncoder(), categorical_cols)    # One-hot encoding categorical features
    ])

knn = KNeighborsClassifier()

param_grid = {
    'classifier__n_neighbors': [3, 5, 7, 10, 15,20,25],
    'classifier__weights': ['uniform', 'distance'],
    'classifier__metric': ['euclidean', 'manhattan'],
    'classifier__leaf_size': [20,30, 40, 50],
    'classifier__p': [1, 2]
}

model = Pipeline(steps=[
    ('preprocessor', preprocessor),
    ('classifier', knn)
])

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)   
grid_search = GridSearchCV(model, param_grid, cv=5, n_jobs=-1, verbose=2)
grid_search.fit(X_train, y_train)  
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)
accuracy=accuracy_score(y_test, y_pred )
print("Accuracy:", accuracy)
# Out:
# Fitting 5 folds for each of 224 candidates, totalling 1120 fits
# Accuracy: 0.9439918533604889
# c:\Users\Istiak\Desktop\Stroke_Predictor(2)\Batman\lib\site-packages\sklearn\model_selection\_search.py:1108: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan]
#   warnings.warn(
